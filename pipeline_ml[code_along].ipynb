# %% [markdown]
# <a href="https://colab.research.google.com/github/ViniiPP/API-EXEMPLO-SIMPLES-JAVA/blob/main/pipeline_ml%5Bcode_along%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pipeline de Machine Learning 101**
#
# Vamos aquecer os motores na jornada para aprender Machine Learning com uma passagem completa, mas básica, pelo pipeline de treinamento de modelos. 🙂
#
# Vamos usar um classificador *dummy* para predizer a probabilidade de você ir ao bar do Zé depois da aula! 🍺

# %%
# imports

# %%
# dados

# %%
# distribuição do alvo

# %%
# split treino-teste

# %%
# autoEDA

# %%
# transformações nos dados

# %%
# aplicar transformações no teste

# %%
# classificador dummy

# %%
# verificar acurácia

# %%
# vamos tentar um tuning

# %% [markdown]
# E como saberemos quais preditores tiveram maior influência no comportamento do modelo?
#
# Neste modelo, não saberemos! Mas nos próximos modelos teremos essa informação 😀
